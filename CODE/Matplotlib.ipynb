# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../DATA/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(dpi=100)
plt.hist(df['SepalLengthCm'])
plt.xticks(rotation=45)
plt.title('Histogram of Sepal Length')
plt.xlabel('Lenght of Sepal')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(dpi=100)
plt.plot(df['PetalLengthCm'])


plt.show()

# %%
plt.figure(dpi=100)
plt.scatter(df['PetalLengthCm'],df['PetalWidthCm'])
plt.title('Scatter Plot: Petal Length vs Petal Width')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')


plt.show()

# %%
plt.figure(dpi=100)
plt.scatter(df['PetalLengthCm'][:75],df['PetalWidthCm'][:75])
plt.scatter(df['PetalLengthCm'][75:],df['PetalWidthCm'][75:])
plt.title('Scatter Plot: Petal Length vs Petal Width')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend(['First Half','Second Half'])


plt.show()

# %%
plt.boxplot([df['PetalWidthCm'],df['PetalLengthCm'],df['SepalWidthCm'],df['SepalLengthCm']])
plt.title('BOX PLOT')

plt.show()

# %%
bins = pd.cut(df['PetalLengthCm'], bins=4).value_counts()
bins
# Out:
# (3.95, 5.425]     61
# (0.994, 2.475]    50
# (5.425, 6.9]      28
# (2.475, 3.95]     11
# Name: PetalLengthCm, dtype: int64

# %%
values = bins.to_list()
labels = [str(x) for x in bins.index.to_list()]

# %%
plt.pie(values, labels=labels)
plt.title('PIE CHART')

plt.show()

# %%
plt.bar(labels,height=values)
plt.title('Bar Chart')

plt.show()
